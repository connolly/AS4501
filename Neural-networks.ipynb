# %% [markdown]
# ## Introduction to Neural Networks
#
# ##### Resources for this notebook include:
# - [Textbook](https://press.princeton.edu/books/hardcover/9780691198309/statistics-data-mining-and-machine-learning-in-astronomy) Chapter 9.8
# - [astroML website](https://www.astroml.org/index.html)
# - [keras Tutorial: Training & evaluation with the built-in methods](https://keras.io/guides/training_with_built_in_methods/)
# - [Deep Learning](https://www.deeplearningbook.org/contents/ml.html) by Goodfellow, Bengio, and Courville, Chapter 5 (free to read online!)
# - [Introduction to (Deep) Neural Networks](https://github.com/AstroHackWeek/AstroHackWeek2020/blob/master/machinelearning-2/astrohackweek_2020_neural_networks.ipynb) by Kyle Boone @ AstroHackWeek 2020 ([recording](https://www.youtube.com/watch?v=2Lpig1WxadU))
#
# This notebook is developed based on material from A. Connolly, Z. Ivezic, M. Juric, S. Portillo, G. Richards, B. Sipocz, J. VanderPlas, D. Hogg, Killian Weinberger and many others.

# %% [markdown]
# ![](images/Neuron-image.jpg)

# %% [markdown]
# ![](images/sinapsis.png)

# %% [markdown]
# ![](images/Neurons.png)

# %% [markdown]
# ![](images/brain.gif)

# %% [markdown]
# ## Neuron pre-activation or input activation
#
#
# $\Large a(x) = b + \sum_i w_i x_i = b + w^T x$
#
# ## Neuron (output) activation
#
# $\Large h(x) = g(a(x)) = g(b + \sum_i w_i x_i)$
#
#
#
# * $\Large \bf w$: connection weights
# * $\Large b$: neuron bias
# * $\Large g(x)$: activation function

# %% [markdown]
# Run this cell to confirm you've got `tensorflow` version >2.8.0 (you may have to restart the kernel).

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.17.0

# %%
import numpy as np

import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib import cm

from astroML.datasets import fetch_sdss_specgals, fetch_rrlyrae_combined
from astroML.utils import split_samples

import pandas as pd

from sklearn.metrics import recall_score, precision_score, ConfusionMatrixDisplay, PrecisionRecallDisplay
from sklearn.neighbors import KNeighborsClassifier

# %%
# make the plots look nice
mpl.rcParams['figure.dpi'] = 150
plt.rc('xtick', labelsize='x-small')
plt.rc('ytick', labelsize='x-small')
plt.rc('legend', fontsize='x-small')
cmap = cm.get_cmap('viridis')
# Out:
# /var/folders/_n/wp9xhwf53ds8mr70wtgy43b40000gn/T/ipykernel_33231/2058960318.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('viridis')

# %% [markdown]
# ![](images/NN.jpeg)

# %% [markdown]
# ## What is a neural network?
#
# **Neural networks** are models that are inspired by biological neurons. They are composed of neurons that:
# - take in multiple inputs $x_i$
# - multiply them by weights $w_i$
# - add a bias (in the below diagram, $\theta$)
# - apply a non-linear activation function $\varphi$ to give an output activation $o$
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/6/60/ArtificialNeuronModel_english.png"> (Chrislb, GFDL)
#
# This activation function can take many forms, like a sigmoid:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/8/88/Logistic-curve.svg">
#
# Neurons are often organized into **layers** which take in the same inputs but apply different weights and biases:
#
# <img src="https://www.astroml.org/_images/fig_neural_network_1.png" />Statistics, Data Mining, and Machine Learning in Astronomy (2020)
#
# If all neurons in a layer are connected to all neurons in the previous layer, then the two layers are **fully connected** and the output of the neurons in the layer can be thought of as a matrix multiplication followed by a non-linear function:
# $$ \vec{o} = \varphi(W \vec{x} + \vec{b})$$
# The **width** of a layer is the number of neurons it has. A network that as a wide **hidden layer** between the input and output can represent any (well-behaved) function, so neural networks are the ultimate in flexible models (Universal approximation theorem (Hornik, 1991)).
#
# However, instead of using an extremely wide network, the same performance can be obtained by having a sequence of layers that take the previous layer's output as their own input. This strategy tends to use fewer neurons overall. The number of layers is the **depth** of the network, and  having at least two **hidden layers** between the network's input and output makes that network **deep**. In deep neural networks, successive layers tend to learn more complex features about the data, reducing the need for feature engineering:
#
# <img src="https://blogs.nvidia.com/wp-content/uploads/2018/07/hierarchical_features.png"> ([NVIDIA blog](https://blogs.nvidia.com/blog/2018/08/02/supervised-unsupervised-learning/))

# %% [markdown]
# ## Photometric redshifts with neural nets

# %% [markdown]
# `astroML` gives us easy access to a [sample of the SDSS galaxies](https://www.astroml.org/modules/generated/astroML.datasets.fetch_sdss_specgals.html): over 600,000 of them! We have a lot of different measurements for each of them, some of them from imaging, others from spectroscopy. We want to see if we can learn the redshifts using only the colors of the galaxies - photometric redshifts. **why do we want to do that?**

# %%
# Fetch and prepare the data
data = fetch_sdss_specgals()
print(data.shape)
print(data.dtype.names)
# Out:
# (661598,)
# ('ra', 'dec', 'mjd', 'plate', 'fiberID', 'z', 'zErr', 'rChi2', 'velDisp', 'velDispErr', 'extinction_r', 'petroMag_r', 'psfMag_r', 'psfMagErr_r', 'modelMag_u', 'modelMagErr_u', 'modelMag_g', 'modelMagErr_g', 'modelMag_r', 'modelMagErr_r', 'modelMag_i', 'modelMagErr_i', 'modelMag_z', 'modelMagErr_z', 'petroR50_r', 'petroR90_r', 'nii_6584_flux', 'nii_6584_flux_err', 'h_alpha_flux', 'h_alpha_flux_err', 'oiii_5007_flux', 'oiii_5007_flux_err', 'h_beta_flux', 'h_beta_flux_err', 'h_delta_flux', 'h_delta_flux_err', 'd4000', 'd4000_err', 'bptclass', 'lgm_tot_p50', 'sfr_tot_p50', 'objID', 'specObjID')

# %% [markdown]
# ### Question: what should we do first?

# %% [markdown]
# We are most interested in the (model-fitting) photometry modelMag in *u*, *g*, *r*, *i*, and *z* bands and the spectroscopic redshifts *z*, because we want to construct a model that predicts redshift from photometry. We'll only use 10% of the data to make our neural nets train faster. Let's make another corner plot.

# %%
# isolate columns we're interested in
features = ['modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i', 'modelMag_z']
target = 'z'
# reduce data set by 10x for demo purposes
df = pd.DataFrame(data[features + [target]])[::10]

# %%
# make a corner plot
fig = plt.figure(figsize=(7.2,7.2))
fig.subplots_adjust(hspace=0, wspace=0)
# loop through every possible pair of features
for i in range(len(features)):
    for j in range(len(features)):
        # only make subplots in the lower diagonal
        if i <= j:
            plt.subplot(6,6,i+j*6+1)
            # if this subplot is on the left side (but not the top), make a y label
            if i == 0 and j != 0:
                plt.ylabel(features[j])
            # if this subplot is on the bottom, make an x label
            if j == 4:
                plt.xlabel(features[i])
            # remove ticks on interior plots
            if i != 0:
                plt.yticks([])
            if j != len(features) - 1:
                plt.xticks([])
            # scatter plots in off diagonals
            if i < j:
                plt.scatter(df[features[i]], df[features[j]], s=1, marker='.', c=df[target], cmap=cmap)
            # histograms on diagonals
            if i == j:
                plt.hist(df[features[i]], histtype='step')
                plt.yticks([]) # don't want counts in the y-axis
plt.show()

# %% [markdown]
# While photometry and redshift are definitely related, the relationships seem fairly complicated. We might think about using colors rather than just magnitudes (this would be **feature engineering**), but let's first see how well a neural network can do with the raw magnitudes.
#
# Let's also hold out 10% of the data as a validation set.

# %%
# take 10% of the data set as the validation set
valid_df = df.sample(frac=0.1, random_state=1)
# remove the validation set to create the training set
train_df = df.drop(valid_df.index)

# %% [markdown]
# ### Backpropagation
#
# Let's set up the neural network from the textbook to do regression on the photometric magnitudes to predict redshift. There will be an input layer of 5 neurons for the 5 magnitudes, a hidden layer of four neurons and an output layer of 1 neuron for the predicted redshift. **We won't use an activation function $g$ for the output, since redshift is unbounded and can be negative.**
#
# **One of the many things Jeff Hinton is known for**
#
# <img src="https://www.astroml.org/_images/fig_neural_network_1.png" />Statistics, Data Mining, and Machine Learning in Astronomy (2020)
#
# Then, the network's predicted redshift for some inputs $x_i$ can be written as:
#
# $$\hat{z} = \sum_{j=1}^4 w_{jk} a_j + b_{k} $$
#
# $$a_j = f\left(\sum_{i=1}^5 w_{ij} x_i + b_j\right) $$
#
#
# We want to minimize a loss function to encourage the network to make better predictions; for regression, we can use the squared error:
# $$ L = \sum_{\ell \in {\rm data}} (z_\ell - \hat{z}_\ell)^2 $$
#
# The network parameters we can change are the weights $w_{ij}$, $w_{jk}$ and biases $b_j$, $b_k$. To change these parameters to minimize the loss function, we need the derivatives of the loss function with respect to the parameters. The derivatives with respect to the output layer aren't bad:
#
# $$ \frac{\partial L}{\partial b_k} = \sum_\ell 2 (z_\ell - \hat{z}_\ell) (-1) $$
#
# $$\frac{\partial L}{\partial w_{jk}} = \sum_\ell 2 (z_\ell - \hat{z}_\ell) (-a_j) $$
#
# To get the derivatives with respect to the hidden layer, we need to apply the chain rule. Doing this computationally efficiently is called **backpropagation**:
#
# $$ \frac{\partial L}{\partial b_j} = \frac{\partial L}{\partial a_j} \frac{\partial a_j}{\partial b_j} = \sum_\ell - 2 (z_\ell - \hat{z}_\ell) w_{jk} \frac{\partial a_j}{\partial b_j}  = - 2 (z_\ell - \hat{z}_\ell) w_{jk} f'\left(\sum_{i=1}^5 w_{ij} x_i + b_j\right)
# $$
#
# $$
# \frac{\partial L}{\partial w_{ij}} = \frac{\partial L}{\partial a_j} \frac{\partial a_j}{\partial w_{ij}} = \sum_\ell - 2 (z_\ell - \hat{z}_\ell) w_{jk} \frac{\partial a_j}{\partial w_{ij}}  = - 2 (z_\ell - \hat{z}_\ell) w_{jk} f'\left(\sum_{i=1}^5 w_{ij} x_i + b_j\right) x_i $$
#
# Because derivatives of the activation function, $f'$, pop up often a common choice for the activation function is the recified linear unit (ReLU):
# $$f(x) = \begin{cases}
# x {\rm \,if\,} x > 0 \\
# 0 {\rm \,if\,} x \leq 0
# \end{cases} $$
# It's non-linear (because of its behaviour at $x \leq 0$) but has a very simple derivative:
# $$f'(x) = \begin{cases}
# 1 {\rm \,if\,} x > 0 \\
# 0 {\rm \,if\,} x < 0
# \end{cases} $$
#
# There exist many software packages like `tensorflow`, `keras`, and `pytorch`, that make it easy to create and train neural networks - they'll do the backpropagation automatically, and feed those derivatives into an optimizer to train your network! We'll be using the `keras` package in this notebook.
#
# ### Training a neural network in keras
#
# One common trick to getting a neural network to train well is to normalize the data. Neural nets are happy when all of the features are of the
# same scale, and ideally have zero mean and unit standard deviation. We'll use the `keras` `Normalization` object that learns the mean and standard deviation of each feature from the training set, and can be used as the first layer of our neural net.
#
# Tricks like these make machine learning more of an art than an exact science - knowing what to do to make your neural network better can be hard, but evaluating your choice is easy - run on the validation set!

# %%
normalizer = tf.keras.layers.Normalization()
normalizer.adapt(train_df[features].to_numpy()) # only use the training set to normalize!

# %% [markdown]
# This next cell of code defines our neural network **architecture**: the inputs (the five photometric magnitudes) are first normalized, and are then followed by a hidden layer of four neurons with ReLU activations, and finally an output layer of one neuron. The activation of this output neuron will be the predicted redshift.

# %%
model = keras.Sequential([
    normalizer, # normalizer
    tf.keras.layers.Dense(4, activation='relu'), # hidden layer
    tf.keras.layers.Dense(1, activation='linear') # predicted redshift
    ])

model.summary()
# Out:
# Model: "sequential_38"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_16                │ (None, 4)              │             9 │
# │ (Normalization)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_78 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_79 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (40.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 9 (40.00 B)

# %% [markdown]
# We then tell `keras` that we want to use the RMSprop **optimizer** to minimize our chosen **loss function**, the mean squared error. We can also tell `keras` to report the root mean squared error, since that has units of redshift.

# %%
model.compile(
    # Optimizer
    optimizer=keras.optimizers.RMSprop(learning_rate=1e-3),
    # Loss function to minimize
    loss=keras.losses.MeanSquaredError(),
    # List of metrics to monitor
    metrics=[keras.metrics.RootMeanSquaredError()],
)

# %% [markdown]
# More machine learning tricks! We will use the `ReduceLROnPlateau` **scheduler** that reduces the **learning rate** by a factor of 10 when the validation loss plateaus for 5 **epochs** (run-throughs of the data set). Often, when the loss plateaus, decreasing the learning rate can yield further improvement.
#
# We will also use the `EarlyStopping` callback to stop training if the validation loss plateaus for 10 epochs. Neural networks are very flexible, so this stops training before too much overfitting to the training set happens. An alternative would be to use some sort of [regularization](https://keras.io/api/layers/regularization_layers/) on the network parameters.

# %%
callbacks = [
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_root_mean_squared_error",
        factor=0.1,
        patience=5,
        verbose=1,
        min_delta=0.0001,
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_root_mean_squared_error",
        min_delta=1e-4,
        patience=10,
        verbose=1,
    )
]

# %% [markdown]
# Finally, we're almost ready to train the neural net! We'll feed in the training data in **minibatches** of 128 and train for a maximum of 100 epochs (runs through the data). The derivatives on the minibatches will, on average, be the same as the derivatives calculated on the entire dataset, but the variability between batches provides stochasticity to help the network get unstuck from local minima. We provide the validation data and link our scheduler and early stopping callbacks so that they have access to the validation data.

# %%
history = model.fit(
    train_df[features],
    train_df[target],
    batch_size=128,
    epochs=100,
    validation_data=(valid_df[features], valid_df[target]),
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.1596 - root_mean_squared_error: 0.3921 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1557 - learning_rate: 0.0010
# Epoch 2/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 0.0073 - root_mean_squared_error: 0.0848 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0695 - learning_rate: 0.0010
# Epoch 3/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step - loss: 0.0030 - root_mean_squared_error: 0.0550 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616 - learning_rate: 0.0010
# Epoch 4/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - loss: 0.0019 - root_mean_squared_error: 0.0437 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0432 - learning_rate: 0.0010
# Epoch 5/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step - loss: 0.0018 - root_mean_squared_error: 0.0420 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0344 - learning_rate: 0.0010
# Epoch 6/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - loss: 0.0021 - root_mean_squared_error: 0.0456 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0321 - learning_rate: 0.0010
# Epoch 7/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - loss: 0.0019 - root_mean_squared_error: 0.0429 - val_loss: 8.5983e-04 - val_root_mean_squared_error: 0.0293 - learning_rate: 0.0010
# Epoch 8/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step - loss: 0.0016 - root_mean_squared_error: 0.0397 - val_loss: 8.3914e-04 - val_root_mean_squared_error: 0.0290 - learning_rate: 0.0010
# Epoch 9/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step - loss: 0.0014 - root_mean_squared_error: 0.0371 - val_loss: 8.1586e-04 - val_root_mean_squared_error: 0.0286 - learning_rate: 0.0010
# Epoch 10/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step - loss: 0.0014 - root_mean_squared_error: 0.0377 - val_loss: 8.0428e-04 - val_root_mean_squared_error: 0.0284 - learning_rate: 0.0010
# Epoch 11/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - loss: 0.0013 - root_mean_squared_error: 0.0363 - val_loss: 8.3321e-04 - val_root_mean_squared_error: 0.0289 - learning_rate: 0.0010
# Epoch 12/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 0.0016 - root_mean_squared_error: 0.0388 - val_loss: 8.1463e-04 - val_root_mean_squared_error: 0.0285 - learning_rate: 0.0010
# Epoch 13/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step - loss: 0.0016 - root_mean_squared_error: 0.0399 - val_loss: 8.3412e-04 - val_root_mean_squared_error: 0.0289 - learning_rate: 0.0010
# Epoch 14/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 7.9926e-04 - val_root_mean_squared_error: 0.0283 - learning_rate: 0.0010
# Epoch 15/100
# 335/466 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - loss: 0.0013 - root_mean_squared_error: 0.0362
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - loss: 0.0013 - root_mean_squared_error: 0.0365 - val_loss: 8.5529e-04 - val_root_mean_squared_error: 0.0292 - learning_rate: 0.0010
# Epoch 16/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step - loss: 0.0014 - root_mean_squared_error: 0.0374 - val_loss: 8.0877e-04 - val_root_mean_squared_error: 0.0284 - learning_rate: 1.0000e-04
# Epoch 17/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 0.0012 - root_mean_squared_error: 0.0352 - val_loss: 8.1353e-04 - val_root_mean_squared_error: 0.0285 - learning_rate: 1.0000e-04
# Epoch 18/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 0.0015 - root_mean_squared_error: 0.0378 - val_loss: 8.0218e-04 - val_root_mean_squared_error: 0.0283 - learning_rate: 1.0000e-04
# Epoch 19/100
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0011 - root_mean_squared_error: 0.0324 - val_loss: 8.0079e-04 - val_root_mean_squared_error: 0.0283 - learning_rate: 1.0000e-04
# Epoch 20/100
# 315/466 ━━━━━━━━━━━━━━━━━━━━ 0s 350us/step - loss: 0.0013 - root_mean_squared_error: 0.0354
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 0.0013 - root_mean_squared_error: 0.0360 - val_loss: 7.9898e-04 - val_root_mean_squared_error: 0.0283 - learning_rate: 1.0000e-04
# Epoch 20: early stopping

# %% [markdown]
# All of the choices we made, like:
# - number of layers
# - activation function
# - loss function
# - optimizer
# - scheduler
# - early stopping / regularization
# - mini-batch size
#
# are **hyperparameters** - in this context, parameters that must be set before training the neural network. Deciding which hyperparameters to focus on limited computer time is part of the art of machine learning. Often, practitioners will conduct **hyperparameter tuning** to find a set of hyperparameters that does well on the validation set. A good first strategy is **random search** - select sets of hyperparameters at random from a defined space, and see what does the best!
#
# Let's see how well this network does on the validation set. Since we're not training, we don't want `keras` to use CPU time doing backpropagation, so we use the `predict` function:

# %%
def plot_redshifts(true_z, pred_z):
    fig = plt.figure(figsize=(5, 5))
    fig.subplots_adjust(wspace=0.25,
                        left=0.1, right=0.95,
                        bottom=0.15, top=0.9)

    ax = plt.axes()
    H, zs_bins, zp_bins = np.histogram2d(pred_z, true_z, 151)
    ax.imshow(H.T, origin='lower', interpolation='nearest', aspect='auto',
               extent=[zs_bins[0], zs_bins[-1], zp_bins[0], zp_bins[-1]],
               cmap=plt.cm.binary)
    ax.plot([-0.1, 0.4], [-0.1, 0.4], ':k')
    rms = np.sqrt(np.mean((true_z - pred_z)**2))
    ax.text(0, 0.35, 'RMS error = %0.3f' % rms)
    ax.set_xlim(-0.02, 0.4001)
    ax.set_ylim(-0.02, 0.4001)
    ax.xaxis.set_major_locator(plt.MultipleLocator(0.1))
    ax.yaxis.set_major_locator(plt.MultipleLocator(0.1))
    ax.set_xlabel(r'$z_{\rm true}$')
    ax.set_ylabel(r'$z_{\rm fit}$')
    plt.show()

# %%
predictions = model.predict(valid_df[features])
plot_redshifts(valid_df[target], predictions.flatten())
# Out:
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step

# %% [markdown]
# ### Exercise: Feature engineering
# Instead of using the raw magnitudes, will the neural net do better if we provide it photometric colors?
#
# Create a neural network that takes colors and predicts photometric redshifts

# %%
# add color columns
df['u-g'] = df['modelMag_u'] - df['modelMag_g']
df['g-r'] = df['modelMag_g'] - df['modelMag_r']
df['r-i'] = df['modelMag_r'] - df['modelMag_i']
df['i-z'] = df['modelMag_i'] - df['modelMag_z']

# take 10% of the data set as the validation set
valid_df = df.sample(frac=0.1, random_state=1)
# remove the validation set to create the training set
train_df = df.drop(valid_df.index)

# now use four colors and r band magnitude
features2 = ['u-g', 'g-r', 'modelMag_r', 'r-i', 'i-z']

# %%
train_df[features2].to_numpy()
# Out:
# array([[ 1.6533251 ,  0.82308006, 14.674012  ,  0.43972397,  0.32674408],
#        [ 2.2372398 ,  1.0244637 , 17.46213   , -1.929327  ,  2.9880276 ],
#        [ 1.4911137 ,  0.7933121 , 16.253967  ,  0.45942688,  0.34089088],
#        ...,
#        [ 1.3758373 ,  0.7885151 , 16.939415  ,  0.35767555,  0.2927513 ],
#        [ 1.723835  ,  0.45661354, 17.655216  ,  0.276165  ,  0.24526405],
#        [ 2.4555016 ,  1.068039  , 17.672653  ,  0.48605728,  0.33774185]],
#       dtype=float32)

# %% [markdown]
# #### your code goes here

# %%
predictions = model2.predict(valid_df[features2])
plot_redshifts(valid_df[target], predictions.flatten())

# %% [markdown]
# ## RR Lyrae classification with neural nets
#
# Let's quickly revisit the RR Lyrae classification with neural nets.

# %%
# fetch the data and print its dimensions
X, y = fetch_rrlyrae_combined()
features = ['u-g', 'g-r', 'r-i', 'i-z']
labels = ['non-variable', 'RR Lyrae']
print('X.shape', X.shape)

# tensor flow wants target as 2D array
y = y.reshape(-1,1)
print('y.shape', y.shape)

# split our data into training and validation sets
# setting random_state makes this split deterministic
(X_train, X_valid, X_test), (y_train, y_valid, y_test) = split_samples(X, y, [0.8, 0.1, 0.1], random_state=0)
# Out:
# X.shape (93141, 4)
# y.shape (93141, 1)

# %% [markdown]
# It turns out this classification problem is harder, so we'll use a **deep** neural net with two hidden layers. Also, the interpretation of the output neuron will be different: we'll use a *sigmoid* activation function on the output neuron to give a probability $p$ between 0 and 1 that a star is an RR Lyrae. If we use the network as a model for the probability of each data point being an RR Lyrae, the likelihood of observing the training set is:
# $$\left(\prod_{i \in {\rm RR\,Lyrae}} p_i\right) \left( \prod_{i \in {\rm not\,variable}} (1-p_i) \right)$$
# Taking the negative log likelihood gives us the *binary cross-entropy*, so minimizing this loss function is doing a maximum likelihood fit!
#
# If we wanted to predict $k>2$ classes, we can generalize this formalism and have an output layer with $k$ neurons, and use the *softmax* activation function to yield $k$ class probabilities that add up to 1. The corresponding negative log likelihood would be the *categorical cross-entropy* loss function.
# $${\rm softmax}(\{\mathcal{O}_i\}) = \left\{\frac{\exp(\mathcal{O}_i)}{\sum_j \exp(\mathcal{O}_j)}\right\}$$

# %%
normalizer = layers.Normalization()
normalizer.adapt(X_train)

model = keras.Sequential([
    normalizer,
    layers.Dense(4, activation='relu'),
    layers.Dense(4, activation='relu'),
    layers.Dense(1, activation='sigmoid') # now this is a probability!
    ])

model.compile(
    # Optimizer
    optimizer=keras.optimizers.RMSprop(learning_rate=1e-3),
    # Loss function to minimize
    loss=keras.losses.BinaryCrossentropy(), # use this loss function for binary classification
    # List of metrics to monitor
    metrics=[keras.metrics.Precision(name='precision'), keras.metrics.Recall(name='recall')],
)

callbacks = [
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.1,
        patience=10,
        verbose=1,
        min_delta=1e-5,
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        min_delta=1e-5,
        patience=20,
        verbose=1,
    )
]

model.summary()

history = model.fit(
    X_train,
    y_train,
    batch_size=4096,
    epochs=300,
    validation_data=(X_valid, y_valid),
    callbacks=callbacks,
    verbose=1
)
# Out:
# Model: "sequential_41"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_19                │ (74512, 4)             │             9 │
# │ (Normalization)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_86 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_87 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_88 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (40.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 9 (40.00 B)
# Epoch 1/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6456 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.5990 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5892 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.5552 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5475 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.5151 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 4/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5082 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.4769 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 5/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4705 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.4393 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 6/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4319 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.4012 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3936 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.3626 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 8/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3530 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.3255 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 9/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3184 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2915 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 10/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2847 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2606 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 11/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2562 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2325 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 12/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2262 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2071 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 13/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2021 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1841 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 14/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1792 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1633 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 15/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1590 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1447 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 16/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1412 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1282 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 17/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1252 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1135 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 18/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1098 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1004 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 19/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0979 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0888 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 20/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0865 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0786 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 21/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0766 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0695 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 22/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0688 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0615 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 23/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0599 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0543 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 24/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0531 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0480 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 25/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0478 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0425 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 26/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0413 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0376 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 27/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0374 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0335 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 28/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0330 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 29/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0311 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0270 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 30/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0275 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0246 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 31/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0260 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0226 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 32/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0231 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0211 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 33/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0224 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0198 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 34/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0204 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0188 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 35/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0204 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0181 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 36/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0203 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0175 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 37/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0190 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0170 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 38/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0199 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0165 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 39/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0170 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0161 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 40/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0173 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0157 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 41/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0161 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0154 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 42/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0172 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0150 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 43/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0163 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0147 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 44/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0158 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0144 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 45/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0152 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0141 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 46/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0157 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0139 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 47/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0158 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0137 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 48/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0152 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0135 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 49/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0150 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0133 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 50/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0154 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0131 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 51/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0149 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0130 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 52/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0146 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0129 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 53/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0147 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0128 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 54/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0150 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0127 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 55/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0142 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0127 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 56/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0142 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0126 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 57/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0138 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0126 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 58/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0145 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0125 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 59/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0134 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0124 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 60/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0138 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0124 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 61/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0143 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0124 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 62/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0137 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0123 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 63/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0129 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0123 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 64/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0137 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0122 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 65/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0145 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0122 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 66/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0140 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0121 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 67/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0141 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0121 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 68/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0139 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0120 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 69/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0129 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0120 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 70/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0130 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0119 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 71/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0132 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0118 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 72/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0135 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0118 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 73/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0128 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0117 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 74/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0133 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0117 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 75/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0133 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0116 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 76/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0127 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0115 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 77/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0139 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0115 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 78/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0125 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0115 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 79/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0133 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0115 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 80/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0132 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0114 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 81/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0119 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0114 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 82/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0125 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0114 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 83/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0128 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0113 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 84/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0134 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0113 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 85/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0113 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 86/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0131 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0112 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 87/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0125 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0112 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 88/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0112 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 89/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0124 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0111 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 90/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0122 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0111 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 91/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0115 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0111 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 92/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0120 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0111 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 93/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0130 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0110 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 94/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0115 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0110 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 95/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0122 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0110 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 96/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0123 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0110 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 97/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0110 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 98/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0122 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0109 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 99/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0109 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 100/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0123 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0109 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 101/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0121 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0109 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 102/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0122 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0109 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 103/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0109 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 104/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0127 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0109 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 105/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0116 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0108 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 106/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0125 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0108 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 107/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0108 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 108/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0118 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0108 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 109/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0119 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0108 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 110/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0113 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0108 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 111/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0118 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0108 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 112/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0122 - precision: 0.1772 - recall: 0.0106 - val_loss: 0.0108 - val_precision: 0.3684 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 113/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0113 - precision: 0.4330 - recall: 0.1258 - val_loss: 0.0107 - val_precision: 0.3529 - val_recall: 0.1333 - learning_rate: 0.0010
# Epoch 114/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0119 - precision: 0.4294 - recall: 0.1156 - val_loss: 0.0107 - val_precision: 0.3889 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 115/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0113 - precision: 0.3994 - recall: 0.1174 - val_loss: 0.0107 - val_precision: 0.3889 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 116/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0120 - precision: 0.4673 - recall: 0.1312 - val_loss: 0.0107 - val_precision: 0.3889 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 117/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0114 - precision: 0.3769 - recall: 0.1105 - val_loss: 0.0107 - val_precision: 0.3889 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 118/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.4995 - recall: 0.1654 - val_loss: 0.0106 - val_precision: 0.3889 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 119/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.4156 - recall: 0.1212 - val_loss: 0.0106 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 120/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.4606 - recall: 0.1256 - val_loss: 0.0106 - val_precision: 0.3889 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 121/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0115 - precision: 0.4000 - recall: 0.1253 - val_loss: 0.0106 - val_precision: 0.3889 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 122/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0113 - precision: 0.4333 - recall: 0.1648 - val_loss: 0.0106 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 123/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.4061 - recall: 0.1286 - val_loss: 0.0106 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 124/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.4213 - recall: 0.1242 - val_loss: 0.0106 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 125/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0114 - precision: 0.4774 - recall: 0.1562 - val_loss: 0.0106 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 126/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0121 - precision: 0.4050 - recall: 0.1299 - val_loss: 0.0106 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 127/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0116 - precision: 0.4214 - recall: 0.1332 - val_loss: 0.0105 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 128/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0116 - precision: 0.4851 - recall: 0.1479 - val_loss: 0.0105 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 129/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - precision: 0.4868 - recall: 0.1436 - val_loss: 0.0105 - val_precision: 0.3889 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 130/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0112 - precision: 0.4702 - recall: 0.1590 - val_loss: 0.0105 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 131/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0110 - precision: 0.4403 - recall: 0.1392 - val_loss: 0.0105 - val_precision: 0.4211 - val_recall: 0.1778 - learning_rate: 0.0010
# Epoch 132/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0112 - precision: 0.5288 - recall: 0.1804 - val_loss: 0.0105 - val_precision: 0.4375 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 133/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0115 - precision: 0.4914 - recall: 0.1576 - val_loss: 0.0105 - val_precision: 0.3889 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 134/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0118 - precision: 0.4469 - recall: 0.1386 - val_loss: 0.0105 - val_precision: 0.4375 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 135/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0112 - precision: 0.5549 - recall: 0.1833 - val_loss: 0.0104 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 136/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0115 - precision: 0.5139 - recall: 0.1396 - val_loss: 0.0104 - val_precision: 0.3889 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 137/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0118 - precision: 0.5069 - recall: 0.1755 - val_loss: 0.0104 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 138/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0110 - precision: 0.4283 - recall: 0.1323 - val_loss: 0.0104 - val_precision: 0.4500 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 139/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0113 - precision: 0.5515 - recall: 0.1897 - val_loss: 0.0104 - val_precision: 0.4500 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 140/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0118 - precision: 0.5605 - recall: 0.2143 - val_loss: 0.0104 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 141/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0118 - precision: 0.5254 - recall: 0.1732 - val_loss: 0.0104 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 142/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0119 - precision: 0.5314 - recall: 0.1737 - val_loss: 0.0104 - val_precision: 0.4444 - val_recall: 0.1778 - learning_rate: 0.0010
# Epoch 143/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0112 - precision: 0.5318 - recall: 0.1753 - val_loss: 0.0103 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 144/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.4462 - recall: 0.1532 - val_loss: 0.0103 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 145/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0113 - precision: 0.4826 - recall: 0.1479 - val_loss: 0.0103 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 146/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0118 - precision: 0.5615 - recall: 0.2220 - val_loss: 0.0103 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 147/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0121 - precision: 0.4553 - recall: 0.1803 - val_loss: 0.0103 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 148/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.5502 - recall: 0.1791 - val_loss: 0.0103 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 149/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0114 - precision: 0.4697 - recall: 0.1738 - val_loss: 0.0103 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 150/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0116 - precision: 0.5435 - recall: 0.1975 - val_loss: 0.0103 - val_precision: 0.4118 - val_recall: 0.1556 - learning_rate: 0.0010
# Epoch 151/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - precision: 0.5960 - recall: 0.1956 - val_loss: 0.0102 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 152/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0112 - precision: 0.5863 - recall: 0.1885 - val_loss: 0.0102 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 153/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109 - precision: 0.5231 - recall: 0.1904 - val_loss: 0.0102 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 154/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0116 - precision: 0.5513 - recall: 0.1703 - val_loss: 0.0102 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 155/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0119 - precision: 0.5042 - recall: 0.1725 - val_loss: 0.0102 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 156/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109 - precision: 0.5712 - recall: 0.1825 - val_loss: 0.0102 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 157/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0113 - precision: 0.5982 - recall: 0.1694 - val_loss: 0.0102 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 158/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0110 - precision: 0.5256 - recall: 0.1890 - val_loss: 0.0101 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 159/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109 - precision: 0.5384 - recall: 0.1825 - val_loss: 0.0102 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 160/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - precision: 0.4992 - recall: 0.1960 - val_loss: 0.0101 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 161/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0111 - precision: 0.5210 - recall: 0.1834 - val_loss: 0.0102 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 162/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0110 - precision: 0.5293 - recall: 0.2102 - val_loss: 0.0102 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 163/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0112 - precision: 0.5299 - recall: 0.2176 - val_loss: 0.0102 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 164/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - precision: 0.5594 - recall: 0.2294 - val_loss: 0.0101 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 165/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0114 - precision: 0.5511 - recall: 0.2065 - val_loss: 0.0101 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 166/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0115 - precision: 0.5443 - recall: 0.1834 - val_loss: 0.0101 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 167/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0112 - precision: 0.5338 - recall: 0.1852 - val_loss: 0.0101 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 168/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0114 - precision: 0.5552 - recall: 0.2294 - val_loss: 0.0101 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 169/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109 - precision: 0.5610 - recall: 0.1947 - val_loss: 0.0101 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 170/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0116 - precision: 0.5719 - recall: 0.2120 - val_loss: 0.0101 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 171/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0111 - precision: 0.5736 - recall: 0.1935 - val_loss: 0.0100 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 172/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0098 - precision: 0.5452 - recall: 0.1950 - val_loss: 0.0101 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 173/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - precision: 0.5492 - recall: 0.2249 - val_loss: 0.0101 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 174/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106 - precision: 0.5840 - recall: 0.2314 - val_loss: 0.0100 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 175/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0113 - precision: 0.5884 - recall: 0.2154 - val_loss: 0.0100 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 176/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0112 - precision: 0.5346 - recall: 0.2119 - val_loss: 0.0100 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 177/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0103 - precision: 0.5745 - recall: 0.2375 - val_loss: 0.0100 - val_precision: 0.4762 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 178/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0115 - precision: 0.4845 - recall: 0.2242 - val_loss: 0.0100 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 179/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109 - precision: 0.5765 - recall: 0.2109 - val_loss: 0.0100 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 180/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0110 - precision: 0.6634 - recall: 0.2496 - val_loss: 0.0100 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 181/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - precision: 0.5383 - recall: 0.1924 - val_loss: 0.0100 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 182/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - precision: 0.6070 - recall: 0.2747 - val_loss: 0.0100 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 183/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0110 - precision: 0.5647 - recall: 0.2147 - val_loss: 0.0100 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 184/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - precision: 0.5476 - recall: 0.2197 - val_loss: 0.0099 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 185/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0111 - precision: 0.5672 - recall: 0.2044 - val_loss: 0.0099 - val_precision: 0.4737 - val_recall: 0.2000 - learning_rate: 0.0010
# Epoch 186/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - precision: 0.6151 - recall: 0.2438 - val_loss: 0.0100 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 187/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - precision: 0.5718 - recall: 0.2384 - val_loss: 0.0099 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 188/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - precision: 0.5494 - recall: 0.2294 - val_loss: 0.0099 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 189/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0105 - precision: 0.5935 - recall: 0.2370 - val_loss: 0.0099 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 190/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0104 - precision: 0.5683 - recall: 0.2299 - val_loss: 0.0099 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 191/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - precision: 0.5193 - recall: 0.2185 - val_loss: 0.0099 - val_precision: 0.5000 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 192/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109 - precision: 0.5912 - recall: 0.2708 - val_loss: 0.0099 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 193/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0105 - precision: 0.6862 - recall: 0.2412 - val_loss: 0.0099 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 194/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - precision: 0.6184 - recall: 0.2591 - val_loss: 0.0098 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 195/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0101 - precision: 0.6043 - recall: 0.2756 - val_loss: 0.0099 - val_precision: 0.5238 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 196/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0110 - precision: 0.6314 - recall: 0.2529 - val_loss: 0.0099 - val_precision: 0.5000 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 197/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0105 - precision: 0.5578 - recall: 0.2470 - val_loss: 0.0099 - val_precision: 0.5417 - val_recall: 0.2889 - learning_rate: 0.0010
# Epoch 198/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - precision: 0.6066 - recall: 0.3207 - val_loss: 0.0098 - val_precision: 0.5000 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 199/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109 - precision: 0.6520 - recall: 0.3011 - val_loss: 0.0098 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 200/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - precision: 0.6572 - recall: 0.2364 - val_loss: 0.0098 - val_precision: 0.5238 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 201/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - precision: 0.5980 - recall: 0.2341 - val_loss: 0.0098 - val_precision: 0.5000 - val_recall: 0.2222 - learning_rate: 0.0010
# Epoch 202/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - precision: 0.6062 - recall: 0.2526 - val_loss: 0.0098 - val_precision: 0.5238 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 203/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0105 - precision: 0.6629 - recall: 0.2426 - val_loss: 0.0098 - val_precision: 0.5000 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 204/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0112 - precision: 0.5706 - recall: 0.2375 - val_loss: 0.0098 - val_precision: 0.5238 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 205/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0104 - precision: 0.6187 - recall: 0.2774 - val_loss: 0.0098 - val_precision: 0.5238 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 206/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0100 - precision: 0.5654 - recall: 0.2302 - val_loss: 0.0098 - val_precision: 0.5000 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 207/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0111 - precision: 0.6123 - recall: 0.2537 - val_loss: 0.0098 - val_precision: 0.5238 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 208/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0104 - precision: 0.6836 - recall: 0.2671 - val_loss: 0.0097 - val_precision: 0.5000 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 209/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0099 - precision: 0.6328 - recall: 0.2754 - val_loss: 0.0098 - val_precision: 0.5600 - val_recall: 0.3111 - learning_rate: 0.0010
# Epoch 210/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0105 - precision: 0.6844 - recall: 0.3465 - val_loss: 0.0098 - val_precision: 0.5000 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 211/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0099 - precision: 0.6497 - recall: 0.2866 - val_loss: 0.0097 - val_precision: 0.5000 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 212/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0104 - precision: 0.6347 - recall: 0.3124 - val_loss: 0.0098 - val_precision: 0.5217 - val_recall: 0.2667 - learning_rate: 0.0010
# Epoch 213/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0110 - precision: 0.6924 - recall: 0.3256 - val_loss: 0.0097 - val_precision: 0.5000 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 214/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106 - precision: 0.6105 - recall: 0.2452 - val_loss: 0.0098 - val_precision: 0.5500 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 215/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106 - precision: 0.6543 - recall: 0.2461 - val_loss: 0.0098 - val_precision: 0.5217 - val_recall: 0.2667 - learning_rate: 0.0010
# Epoch 216/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109 - precision: 0.6624 - recall: 0.3021 - val_loss: 0.0097 - val_precision: 0.5000 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 217/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106 - precision: 0.6357 - recall: 0.2890 - val_loss: 0.0098 - val_precision: 0.5217 - val_recall: 0.2667 - learning_rate: 0.0010
# Epoch 218/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - precision: 0.6163 - recall: 0.2594 - val_loss: 0.0097 - val_precision: 0.5417 - val_recall: 0.2889 - learning_rate: 0.0010
# Epoch 219/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0114 - precision: 0.6568 - recall: 0.3417 - val_loss: 0.0097 - val_precision: 0.5217 - val_recall: 0.2667 - learning_rate: 0.0010
# Epoch 220/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0099 - precision: 0.6729 - recall: 0.3055 - val_loss: 0.0097 - val_precision: 0.5217 - val_recall: 0.2667 - learning_rate: 0.0010
# Epoch 221/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - precision: 0.6467 - recall: 0.2945 - val_loss: 0.0097 - val_precision: 0.5000 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 222/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0103 - precision: 0.6557 - recall: 0.2837 - val_loss: 0.0097 - val_precision: 0.5217 - val_recall: 0.2667 - learning_rate: 0.0010
# Epoch 223/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - precision: 0.6514 - recall: 0.2872 - val_loss: 0.0097 - val_precision: 0.5217 - val_recall: 0.2667 - learning_rate: 0.0010
# Epoch 224/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109 - precision: 0.6095 - recall: 0.2705 - val_loss: 0.0097 - val_precision: 0.5000 - val_recall: 0.2444 - learning_rate: 0.0010
# Epoch 225/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106 - precision: 0.6814 - recall: 0.2895 - val_loss: 0.0096 - val_precision: 0.5417 - val_recall: 0.2889 - learning_rate: 0.0010
# Epoch 226/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0098 - precision: 0.6946 - recall: 0.3194 - val_loss: 0.0097 - val_precision: 0.5417 - val_recall: 0.2889 - learning_rate: 0.0010
# Epoch 227/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - precision: 0.6737 - recall: 0.3274 - val_loss: 0.0097 - val_precision: 0.5417 - val_recall: 0.2889 - learning_rate: 0.0010
# Epoch 228/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - precision: 0.6821 - recall: 0.3391 - val_loss: 0.0097 - val_precision: 0.5769 - val_recall: 0.3333 - learning_rate: 0.0010
# Epoch 229/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0105 - precision: 0.6820 - recall: 0.3089 - val_loss: 0.0097 - val_precision: 0.5417 - val_recall: 0.2889 - learning_rate: 0.0010
# Epoch 230/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0105 - precision: 0.6787 - recall: 0.2865 - val_loss: 0.0096 - val_precision: 0.5417 - val_recall: 0.2889 - learning_rate: 0.0010
# Epoch 231/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - precision: 0.6619 - recall: 0.2999 - val_loss: 0.0096 - val_precision: 0.5417 - val_recall: 0.2889 - learning_rate: 0.0010
# Epoch 232/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - precision: 0.6797 - recall: 0.3117 - val_loss: 0.0096 - val_precision: 0.5217 - val_recall: 0.2667 - learning_rate: 0.0010
# Epoch 233/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0099 - precision: 0.6891 - recall: 0.3225 - val_loss: 0.0097 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 0.0010
# Epoch 234/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0110 - precision: 0.6964 - recall: 0.3486 - val_loss: 0.0096 - val_precision: 0.5417 - val_recall: 0.2889 - learning_rate: 0.0010
# Epoch 235/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - precision: 0.6900 - recall: 0.3593 - val_loss: 0.0096 - val_precision: 0.5217 - val_recall: 0.2667 - learning_rate: 0.0010
# Epoch 236/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0101 - precision: 0.7092 - recall: 0.3591 - val_loss: 0.0095 - val_precision: 0.5769 - val_recall: 0.3333 - learning_rate: 0.0010
# Epoch 237/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - precision: 0.5932 - recall: 0.3007 - val_loss: 0.0096 - val_precision: 0.5217 - val_recall: 0.2667 - learning_rate: 0.0010
# Epoch 238/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0111 - precision: 0.6447 - recall: 0.3044 - val_loss: 0.0096 - val_precision: 0.5217 - val_recall: 0.2667 - learning_rate: 0.0010
# Epoch 239/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0100 - precision: 0.7043 - recall: 0.3261 - val_loss: 0.0096 - val_precision: 0.5417 - val_recall: 0.2889 - learning_rate: 0.0010
# Epoch 240/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106 - precision: 0.6767 - recall: 0.3444 - val_loss: 0.0096 - val_precision: 0.6207 - val_recall: 0.4000 - learning_rate: 0.0010
# Epoch 241/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0100 - precision: 0.6579 - recall: 0.4186 - val_loss: 0.0095 - val_precision: 0.5417 - val_recall: 0.2889 - learning_rate: 0.0010
# Epoch 242/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0099 - precision: 0.6995 - recall: 0.3168 - val_loss: 0.0095 - val_precision: 0.5417 - val_recall: 0.2889 - learning_rate: 0.0010
# Epoch 243/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0101 - precision: 0.6736 - recall: 0.3383 - val_loss: 0.0096 - val_precision: 0.5600 - val_recall: 0.3111 - learning_rate: 0.0010
# Epoch 244/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0105 - precision: 0.6678 - recall: 0.3344 - val_loss: 0.0095 - val_precision: 0.5769 - val_recall: 0.3333 - learning_rate: 0.0010
# Epoch 245/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - precision: 0.6622 - recall: 0.3480 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 0.0010
# Epoch 246/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - precision: 0.6341 - recall: 0.3240 - val_loss: 0.0095 - val_precision: 0.6207 - val_recall: 0.4000 - learning_rate: 0.0010
# Epoch 247/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0096 - precision: 0.6633 - recall: 0.3226 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 0.0010
# Epoch 248/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0105 - precision: 0.6572 - recall: 0.3720 - val_loss: 0.0095 - val_precision: 0.5417 - val_recall: 0.2889 - learning_rate: 0.0010
# Epoch 249/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0095 - precision: 0.6726 - recall: 0.3453 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 0.0010
# Epoch 250/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106 - precision: 0.6368 - recall: 0.3312 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 0.0010
# Epoch 251/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0104 - precision: 0.6766 - recall: 0.3533 - val_loss: 0.0095 - val_precision: 0.5600 - val_recall: 0.3111 - learning_rate: 0.0010
# Epoch 252/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0100 - precision: 0.6547 - recall: 0.3181 - val_loss: 0.0095 - val_precision: 0.6333 - val_recall: 0.4222 - learning_rate: 0.0010
# Epoch 253/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0098 - precision: 0.6502 - recall: 0.3722 - val_loss: 0.0095 - val_precision: 0.6333 - val_recall: 0.4222 - learning_rate: 0.0010
# Epoch 254/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0104 - precision: 0.6465 - recall: 0.3688 - val_loss: 0.0095 - val_precision: 0.6207 - val_recall: 0.4000 - learning_rate: 0.0010
# Epoch 255/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0097 - precision: 0.7198 - recall: 0.3976 - val_loss: 0.0095 - val_precision: 0.6333 - val_recall: 0.4222 - learning_rate: 0.0010
# Epoch 256/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - precision: 0.6646 - recall: 0.3844 - val_loss: 0.0095 - val_precision: 0.5926 - val_recall: 0.3556 - learning_rate: 0.0010
# Epoch 257/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106 - precision: 0.6518 - recall: 0.2953 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 0.0010
# Epoch 258/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0100 - precision: 0.6818 - recall: 0.3787 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 0.0010
# Epoch 259/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0101 - precision: 0.6708 - recall: 0.3549 - val_loss: 0.0095 - val_precision: 0.5600 - val_recall: 0.3111 - learning_rate: 0.0010
# Epoch 260/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106 - precision: 0.6786 - recall: 0.3541 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 0.0010
# Epoch 261/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0105 - precision: 0.6629 - recall: 0.3471 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 0.0010
# Epoch 262/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0100 - precision: 0.6913 - recall: 0.4047 - val_loss: 0.0095 - val_precision: 0.5926 - val_recall: 0.3556 - learning_rate: 0.0010
# Epoch 263/300
#  3/19 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.0111 - precision: 0.7399 - recall: 0.3105
# Epoch 263: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0104 - precision: 0.6769 - recall: 0.3442 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 0.0010
# Epoch 264/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0110 - precision: 0.6437 - recall: 0.3281 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 1.0000e-04
# Epoch 265/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0100 - precision: 0.7022 - recall: 0.3176 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 1.0000e-04
# Epoch 266/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - precision: 0.6893 - recall: 0.3245 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 1.0000e-04
# Epoch 267/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - precision: 0.7002 - recall: 0.3572 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 1.0000e-04
# Epoch 268/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - precision: 0.6375 - recall: 0.3165 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 1.0000e-04
# Epoch 269/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0094 - precision: 0.6777 - recall: 0.3500 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 1.0000e-04
# Epoch 270/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - precision: 0.6660 - recall: 0.3526 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 1.0000e-04
# Epoch 271/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109 - precision: 0.6802 - recall: 0.3713 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 1.0000e-04
# Epoch 272/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0105 - precision: 0.6160 - recall: 0.3513 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 1.0000e-04
# Epoch 273/300
#  3/19 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 0.0103 - precision: 0.7706 - recall: 0.5060
# Epoch 273: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0103 - precision: 0.6961 - recall: 0.3985 - val_loss: 0.0095 - val_precision: 0.6071 - val_recall: 0.3778 - learning_rate: 1.0000e-04
# Epoch 273: early stopping

# %% [markdown]
# ### Question
# I used such large minibatches in training - what property of the dataset would motivate my choice?

# %%
# get predicted probabilities on test set
# convert back to 1D array to make scikit-learn happier
predictions_probability = model.predict(X_test).reshape(-1)
# convert to class prediction with 50% threshold
predictions_class = predictions_probability > 0.5

# plot confusion matrix
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot()
ConfusionMatrixDisplay.from_predictions(y_test, predictions_class, cmap='Blues', display_labels=labels, ax=ax)
plt.show()

# when there are only two classes, scikit-learn will calculate the precision/recall for class=1 only
print('RR Lyrae Recall %0.3f' % recall_score(y_test, predictions_class))
print('RR Lyrae Precision %0.3f' % precision_score(y_test, predictions_class))
# Out:
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step
# RR Lyrae Recall 0.391
# RR Lyrae Precision 0.758

# %% [markdown]
# When using neural networks, it's always good to compare to a simpler baseline model to see how much performance your neural network is really giving you. Here I compare the neural net to a $k=5$ nearest neighbors classifier.

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train[:,0])

knn_log_proba = knn.predict_proba(X_test)[:, 1]

fig = plt.figure()
ax = fig.add_subplot()

PrecisionRecallDisplay.from_predictions(y_test[:,0], knn_log_proba, label='KNN', ax=ax)
PrecisionRecallDisplay.from_predictions(y_test[:,0], predictions_probability, label='neural net', ax=ax)

plt.show()

# %% [markdown]
# ### Exercise: Build a model that improves on this classification ####
